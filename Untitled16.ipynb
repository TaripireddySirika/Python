# %% [markdown]
# <a href="https://colab.research.google.com/github/TaripireddySirika/Python/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input())
if(a<=10):
  print("false")
else:
  print("true")
# Out:
# 3
# false

# %%
a=input()
if(a=="green"):
  print("found")
else:
  print("notfound")
# Out:
# Green
# notfound

# %%
a=int(input())
if(a<=10):
  print("uma")
elif(a==10):
    print("siri")
else:
  print("none")
# Out:
# 10
# uma

# %%
a=int(input())
if(a>20):
  print("Charge")
elif(20>=50):
    print("use")
else:
  print("moreuse")
# Out:
# 25
# Charge

# %%
for i in range(2,10,2):
    print(i)
# Out:
# 2
# 4
# 6
# 8

# %%
fruit = ["apple","banana","grapes"]
for i in fruit:
  print(i)
# Out:
# apple
# banana
# grapes
